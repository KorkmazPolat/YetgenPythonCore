# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
vi = float(input("İlk hız değeri:"))
a = float(input("İvme değerini giriniz:"))
t = float(input("Zaman değerini giriniz:"))

def sonHız(vi,a,t):
    vf = float(vi+a*t)
    print("Son hız:", vf)

sonHız(vi,a,t)
# Out:
# Son hız: 115.0

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def is_perfect(num):
    sum_divisors = sum([i for i in range(1, num) if num % i == 0])
    return sum_divisors == num

for i in range(1, 1001):
    if is_perfect(i):
        print(i, "is a perfect number")
# Out:
# 6 is a perfect number
# 28 is a perfect number
# 496 is a perfect number

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def print_pythagorean_triples():
    for a in range(1, 101):
        for b in range(a, 101):
            for c in range(b, 101):
                if a*a + b*b == c*c:
                    print(a, b, c)

print_pythagorean_triples()
# Out:
# 3 4 5
# 5 12 13
# 6 8 10
# 7 24 25
# 8 15 17
# 9 12 15
# 9 40 41
# 10 24 26
# 11 60 61
# 12 16 20
# 12 35 37
# 13 84 85
# 14 48 50
# 15 20 25
# 15 36 39
# 16 30 34
# 16 63 65
# 18 24 30
# 18 80 82
# 20 21 29
# 20 48 52
# 21 28 35
# 21 72 75
# 24 32 40
# 24 45 51
# 24 70 74
# 25 60 65
# 27 36 45
# 28 45 53
# 28 96 100
# 30 40 50
# 30 72 78
# 32 60 68
# 33 44 55
# 33 56 65
# 35 84 91
# 36 48 60
# 36 77 85
# 39 52 65
# 39 80 89
# 40 42 58
# 40 75 85
# 42 56 70
# 45 60 75
# 48 55 73
# 48 64 80
# 51 68 85
# 54 72 90
# 57 76 95
# 60 63 87
# 60 80 100
# 65 72 97

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math

def calculate_paint_cans(height, width):
    area = height * width
    cans = math.ceil(area / 5)
    return cans

# Example usage
height = 2.5   # meters
width = 10.0   # meters
num_cans = calculate_paint_cans(height, width)
print("You need to buy", num_cans, "cans of paint.")
# Out:
# You need to buy 5 cans of paint.

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
def count_vowels_consonants(word):
    vowels = ['a', 'e', 'i', 'o', 'u']
    vowel_count = 0
    consonant_count = 0

    for letter in word:
        if letter.lower() in vowels:
            vowel_count += 1
        elif letter.isalpha():
            consonant_count += 1
    
    counts = {'vowels': vowel_count, 'consonants': consonant_count}
    return counts

word = "Hello World"
counts = count_vowels_consonants(word)
print(counts)
# Out:
# {'vowels': 3, 'consonants': 7}

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def even_numbers(numbers_list):
    even_list = []
    for num in numbers_list:
        if num % 2 == 0:
            even_list.append(num)
    return even_list

numbers_list = [1,45,78,69,14,32,78,12,35,75,12,78,45,75,76,7,6]
evennumbers = even_numbers(numbers_list)
print(evennumbers)
# Out:
# [78, 14, 32, 78, 12, 12, 78, 76, 6]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def sum_recursive(n):
    if n == 0:
        return 0
    else:
        return n + sum_recursive(n-1)
    
result = sum_recursive(10)
print(result)
# Out:
# 55
